# %%
# pip install -U spacy
# python -m spacy download en_core_web_sm
import spacy

# Load English tokenizer, tagger, parser and NER
nlp = spacy.load("en_core_web_sm")

# Process whole documents
text = ("When Sebastian Thrun started working on self-driving cars at "
        "Google in 2007, few people outside of the company took him "
        "seriously. “I can tell you very senior CEOs of major American "
        "car companies would shake my hand and turn away because I wasn’t "
        "worth talking to,” said Thrun, in an interview with Recode earlier "
        "this week.")
doc = nlp(text)

# Analyze syntax
print("Noun phrases:", [chunk.text for chunk in doc.noun_chunks])
print("Verbs:", [token.lemma_ for token in doc if token.pos_ == "VERB"])

# Find named entities, phrases and concepts
for entity in doc.ents:
    print(entity.text, entity.label_)
# Out:
# Noun phrases: ['Sebastian Thrun', 'self-driving cars', 'Google', 'few people', 'the company', 'him', 'I', 'you', 'very senior CEOs', 'major American car companies', 'my hand', 'I', 'Thrun', 'an interview', 'Recode']
# Verbs: ['start', 'work', 'drive', 'take', 'can', 'tell', 'would', 'shake', 'turn', 'talk', 'say']
# Sebastian NORP
# Google ORG
# 2007 DATE
# American NORP
# Recode ORG
# earlier this week DATE

# %%
pip install pytesseract
# Out:
# ...
#   Created wheel for pytesseract: filename=pytesseract-0.3.8-py2.py3-none-any.whl size=14070 sha256=0225e3d0580157cc706702d3cba32d956df1eb066c55b00597405b08ffd07664
#   Stored in directory: /root/.cache/pip/wheels/a4/89/b9/3f11250225d0f90e5454fcc30fd1b7208db226850715aa9ace
# Successfully built pytesseract
# ...

# %%
pip install pdf2image

# %%
pip install python-poppler
# Out:
# ...
#      |████████████████████████████████| 595 kB 7.8 MB/s
# ...
#   ERROR: Failed building wheel for python-poppler
#   Running setup.py clean for python-poppler
# Failed to build python-poppler
# ...
#     Running setup.py install for python-poppler ... error
# ...

# %%
pip install image
# Out:
# ...
#      |████████████████████████████████| 7.9 MB 4.1 MB/s
# ...
#   Created wheel for image: filename=image-1.5.33-py2.py3-none-any.whl size=19496 sha256=79a062ccaf309b359a8554e06ddad3d9f91813743d55e93cda152d2bf9132c2e
#   Stored in directory: /root/.cache/pip/wheels/56/88/e6/897194cfe8c08a8b9afd881d3bf53d102e13fa39607d721383
# Successfully built image
# ...

# %%
from PIL import Image
import pytesseract
import sys
from pdf2image import convert_from_path
import os

PDF_file = "/content/sample_data/Shubham_Modi_CV_Old.pdf"
#Store all the pages in pages variable. Here 500 is resolution
pages = convert_from_path(PDF_file, 500)
image_counter = 1

for page in pages:
    filename = "page_"+str(image_counter)+".jpg"
    page.save(filename, 'JPEG')
    image_counter = image_counter + 1
filelimit = image_counter-1

outfile = "out_text.txt"
f = open(outfile, "a")
finaloutput=[]
for i in range(1, filelimit + 1):
    filename = "page_"+str(i)+".jpg"
    text = str(((pytesseract.image_to_string(Image.open(filename)))))
    text = text.replace('-\n', '')
    finaloutput.append(text)
    f.write(text)

f.close()
print(finaloutput)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pdf2image/pdf2image.py in pdfinfo_from_path(pdf_path, userpw, poppler_path, rawdates, timeout)
#     457             env["LD_LIBRARY_PATH"] = poppler_path + ":" + env.get("LD_LIBRARY_PATH", "")
# --> 458         proc = Popen(command, env=env, stdout=PIPE, stderr=PIPE)
#     459
#
# /usr/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     799                                 errread, errwrite,
# --> 800                                 restore_signals, start_new_session)
#     801         except:
#
# ...

# %%
pip install pillow

# %%
pip install pytesseract

# %%
from PIL import Image
import pytesseract
import cv2
import re
import os
import webbrowser

img=cv2.imread("/content/sample_data/Testing.png")

gray=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

file="{}.png" .format(os.getpid())
cv2.imwrite(file,gray)

text=pytesseract.image_to_string(Image.open(file))
os.remove(file)

print(text)


urls = re.findall('http[s]?://(?:[a-zA-Z]|[0-9]|[.]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', text)

print(urls[0])

webbrowser.open(urls[0])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pytesseract/pytesseract.py in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     251     try:
# --> 252         proc = subprocess.Popen(cmd_args, **subprocess_args())
#     253     except OSError as e:
#
# /usr/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     799                                 errread, errwrite,
# --> 800                                 restore_signals, start_new_session)
#     801         except:
#
# ...

# %%
for i in finaloutput:
    doc = nlp(i)

    # Analyze syntax
    print("Noun phrases:", [chunk.text for chunk in doc.noun_chunks])
    print("Verbs:", [token.lemma_ for token in doc if token.pos_ == "VERB"])

    # Find named entities, phrases and concepts
    for entity in doc.ents:
        print(entity.text, entity.label_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-9ab06545a105> in <module>()
# ----> 1 for i in finaloutput:
#       2     doc = nlp(i)
#       3
#       4     # Analyze syntax
#       5     print("Noun phrases:", [chunk.text for chunk in doc.noun_chunks])
#
# NameError: name 'finaloutput' is not defined

# %%
from PIL import Image
import pytesseract
import cv2
import re
import os
import webbrowser

tss.pytesseract.tesseract_cmd = r'/opt/homebrew/bin/tesseract'

img=cv2.imread("/content/sample_data/Testing.png")

gray=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

file="{}.png" .format(os.getpid())
cv2.imwrite(file,gray)

text=pytesseract.image_to_string(Image.open(file))
os.remove(file)

print(text)


urls = re.findall('http[s]?://(?:[a-zA-Z]|[0-9]|[.]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', text)

print(urls[0])

webbrowser.open(urls[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-4d4a147b6092> in <module>()
#       6 import webbrowser
#       7
# ----> 8 tss.pytesseract.tesseract_cmd = r'/opt/homebrew/bin/tesseract'
#       9
#      10 img=cv2.imread("/content/sample_data/Testing.png")
#
# NameError: name 'tss' is not defined

# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files (x86)\Tesseract-OCR\tesseract'
print(pytesseract.image_to_string(r'test1.png'))

# %%
pip install opencv-python

# %%
pip install pdf2image

# %%
from pdf2image import convert_from_path
pages = convert_from_path('/content/sample_data/Shubham_Modi_CV_Old.pdf', 500)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pdf2image/pdf2image.py in pdfinfo_from_path(pdf_path, userpw, poppler_path, rawdates, timeout)
#     457             env["LD_LIBRARY_PATH"] = poppler_path + ":" + env.get("LD_LIBRARY_PATH", "")
# --> 458         proc = Popen(command, env=env, stdout=PIPE, stderr=PIPE)
#     459
#
# /usr/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     799                                 errread, errwrite,
# --> 800                                 restore_signals, start_new_session)
#     801         except:
#
# ...

# %%
from PIL import Image
import pytesseract
import cv2
import re
import os
import webbrowser

img=cv2.imread("/content/sample_data/Testing.png")

gray=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

file="{}.png" .format(os.getpid())
cv2.imwrite(file,gray)

text=pytesseract.image_to_string(Image.open(file))
os.remove(file)

print(text)


urls = re.findall('http[s]?://(?:[a-zA-Z]|[0-9]|[.]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', text)

print(urls[0])

webbrowser.open(urls[0])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pytesseract/pytesseract.py in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     251     try:
# --> 252         proc = subprocess.Popen(cmd_args, **subprocess_args())
#     253     except OSError as e:
#
# /usr/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     799                                 errread, errwrite,
# --> 800                                 restore_signals, start_new_session)
#     801         except:
#
# ...

# %%
pip install python-poppler
# Out:
# ...
#   Using cached python-poppler-0.2.2.tar.gz (595 kB)
# ...
#   ERROR: Failed building wheel for python-poppler
#   Running setup.py clean for python-poppler
# Failed to build python-poppler
# ...
#     Running setup.py install for python-poppler ... error
# ...
